# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
# @hidden_cell

CLIENT_ID = 'ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y' # your Foursquare ID
CLIENT_SECRET = 'CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y
# CLIENT_SECRET:CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF

# %%
address_sorrento = 'Sorrento, Italy'

geolocator = Nominatim(user_agent="foursquare_agent")
location_sorrento = geolocator.geocode(address_sorrento)
latitude_sorrento = location.latitude
longitude_sorrento = location.longitude
print(latitude_sorrento, longitude_sorrento)
# Out:
# 40.624906 14.374836

# %%
search_query_sorrento = '4bf58dd8d48988d110941735' # Italian restaurants in Sorrento search results using a Foursquare category code
radius = 1000
limit = 100
print(' .... OK!')
# Out:
#  .... OK!

# %%
# Formatting for url search

url_sorrento = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(search_query_sorrento, CLIENT_ID, CLIENT_SECRET, latitude_sorrento, longitude_sorrento, VERSION, radius, limit)
url_sorrento
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d110941735&client_id=ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y&client_secret=CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF&ll=40.624906,14.374836&v=20180604&radius=1000&limit=100'

# %%
df_sorrento = requests.get(url_sorrento).json()
print('df_sorrento created')
# Out:
# df_sorrento created

# %%
# assign relevant part of JSON to venues
venues_sorrento1 = df_sorrento['response']['venues']

# tranform venues into a dataframe
df_sorrento_italian = json_normalize(venues_sorrento1)
df_sorrento_italian.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  4deab6b7fa76cc1b8aed74da                  Taverna Allegra
# 1  4fac1172e4b0256bff1842fe   Ristorante I Giardini Di Tasso
# 2  4c1401a1a5eb76b01807c1b7           Ristorante La Lanterna
# 3  4e3ef11118a83d5b2858e7e5  Ristorante Pizzeria S. Antonino
# 4  5083ea51e4b00b2c40edb295       Ristorante Pizzeria Aurora
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878702    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878702    False
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1590878702    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878702    False
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1590878702    False
#
#                         location.address  location.lat  location.lng  \
# 0                    Via della Pietà, 30     40.625331     14.374490
# 1                33 Via S.M. Della Pietà     40.624901     14.374449
# 2                  Via San Cesareo 23/25     40.626288     14.374937
# 3  Via S. Maria delle Grazie, 6 Sorrento     40.626590     14.374230
# 4                       Piazza Tasso, 11     40.626189     14.376010
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.62533070025635...                 55
# 1  [{'label': 'display', 'lat': 40.6249006686078,...                 32
# 2  [{'label': 'display', 'lat': 40.6262879, 'lng'...                154
# 3  [{'label': 'display', 'lat': 40.62658956072927...                194
# 4  [{'label': 'display', 'lat': 40.62618875409959...                173
#
#   location.postalCode location.cc location.city  \
# 0               80067          IT      Sorrento
# 1               80067          IT      Sorrento
# 2               80067          IT      Sorrento
# 3                 NaN          IT      Sorrento
# 4                 NaN          IT      Sorrento
#
#                   location.state location.country  \
# 0                       Campania           Italia
# 1                       Campania           Italia
# 2  Città Metropolitana di Napoli           Italia
# 3                       Campania           Italia
# 4                       Campania           Italia
#
#                            location.formattedAddress location.crossStreet
# 0  [Via della Pietà, 30, 80067 Sorrento Campania,...                  NaN
# 1  [33 Via S.M. Della Pietà, 80067 Sorrento Campa...                  NaN
# 2  [Via San Cesareo 23/25, 80067 Sorrento Città M...                  NaN
# 3  [Via S. Maria delle Grazie, 6 Sorrento, Sorren...                  NaN
# 4      [Piazza Tasso, 11, Sorrento Campania, Italia]                  NaN

# %%
df_sorrento_italian.shape
# Out:
# (50, 17)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_sorrento_italian.columns if col.startswith('location.')] + ['id']
df_sorrento_IT_filtered = df_sorrento_italian.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sorrento_IT_filtered['categories'] = df_sorrento_IT_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sorrento_IT_filtered.columns = [column.split('.')[-1] for column in df_sorrento_IT_filtered.columns]

df_sorrento_IT_filtered.head()
# Out:
#                               name          categories  \
# 0                  Taverna Allegra  Italian Restaurant
# 1   Ristorante I Giardini Di Tasso  Italian Restaurant
# 2           Ristorante La Lanterna         Pizza Place
# 3  Ristorante Pizzeria S. Antonino  Italian Restaurant
# 4       Ristorante Pizzeria Aurora         Pizza Place
#
#                                  address        lat        lng  \
# 0                    Via della Pietà, 30  40.625331  14.374490
# 1                33 Via S.M. Della Pietà  40.624901  14.374449
# 2                  Via San Cesareo 23/25  40.626288  14.374937
# 3  Via S. Maria delle Grazie, 6 Sorrento  40.626590  14.374230
# 4                       Piazza Tasso, 11  40.626189  14.376010
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.62533070025635...        55      80067  IT
# 1  [{'label': 'display', 'lat': 40.6249006686078,...        32      80067  IT
# 2  [{'label': 'display', 'lat': 40.6262879, 'lng'...       154      80067  IT
# 3  [{'label': 'display', 'lat': 40.62658956072927...       194        NaN  IT
# 4  [{'label': 'display', 'lat': 40.62618875409959...       173        NaN  IT
#
#        city                          state country  \
# 0  Sorrento                       Campania  Italia
# 1  Sorrento                       Campania  Italia
# 2  Sorrento  Città Metropolitana di Napoli  Italia
# 3  Sorrento                       Campania  Italia
# 4  Sorrento                       Campania  Italia
#
#                                     formattedAddress crossStreet  \
# 0  [Via della Pietà, 30, 80067 Sorrento Campania,...         NaN
# 1  [33 Via S.M. Della Pietà, 80067 Sorrento Campa...         NaN
# 2  [Via San Cesareo 23/25, 80067 Sorrento Città M...         NaN
# 3  [Via S. Maria delle Grazie, 6 Sorrento, Sorren...         NaN
# 4      [Piazza Tasso, 11, Sorrento Campania, Italia]         NaN
#
#                          id
# 0  4deab6b7fa76cc1b8aed74da
# 1  4fac1172e4b0256bff1842fe
# 2  4c1401a1a5eb76b01807c1b7
# 3  4e3ef11118a83d5b2858e7e5
# 4  5083ea51e4b00b2c40edb295

# %%
search_query_sorrento1 = '4d4b7105d754a06374d81259' # Food places in Sorrento search results using a Foursquare category code
radius = 1000
limit = 100
print(' .... OK!')
# Out:
#  .... OK!

# %%
# Formatting for url search

url_sorrento1 = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(search_query_sorrento1, CLIENT_ID, CLIENT_SECRET, latitude_sorrento, longitude_sorrento, VERSION, radius, limit)
url_sorrento1
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4d4b7105d754a06374d81259&client_id=ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y&client_secret=CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF&ll=40.624906,14.374836&v=20180604&radius=1000&limit=100'

# %%
df_sorrento1 = requests.get(url_sorrento1).json()
print('df_sorrento1 created')
# Out:
# df_sorrento1 created

# %%
# assign relevant part of JSON to venues
venues_sorrento2 = df_sorrento1['response']['venues']

# tranform venues into a dataframe
df_sorrento_food = json_normalize(venues_sorrento2)
df_sorrento_food.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                       name  \
# 0  5542832d498ec52eb43563af                 Piccadilly
# 1  4cdea8af78ddf04d0fdb9b98      Sedil Dominova "2000"
# 2  4c62d41dec94a593c9332aca  Gelateria Antonio Cafiero
# 3  5da5980318ef670008a39a19                Fatto Mo Mo
# 4  5b2c10322619ee002cc82178    Gelateria Chist' Ammore
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590878703    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878703    False
# 2  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...  v-1590878703    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878703    False
# 4  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...  v-1590878703    False
#
#    location.lat  location.lng  \
# 0     40.624804     14.376910
# 1     40.626030     14.373421
# 2     40.626058     14.374916
# 3     40.625912     14.372960
# 4     40.625990     14.374684
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.62480405205569...                175
# 1  [{'label': 'display', 'lat': 40.62603038416951...                173
# 2  [{'label': 'display', 'lat': 40.626058, 'lng':...                128
# 3  [{'label': 'display', 'lat': 40.625912, 'lng':...                194
# 4  [{'label': 'display', 'lat': 40.62599, 'lng': ...                121
#
#   location.cc location.country  \
# 0          IT           Italia
# 1          IT           Italia
# 2          IT           Italia
# 3          IT           Italia
# 4          IT           Italia
#
#                            location.formattedAddress  \
# 0                                           [Italia]
# 1           [Senso Unico, Sorrento Campania, Italia]
# 2          [Corso Italia, Sorrento Campania, Italia]
# 3  [Via San Cesareo, 80067 Sorrento Campania, Ita...
# 4  [Corso Italia, 134, 80067 Sorrento NA, Italy, ...
#
#                               location.address location.city location.state  \
# 0                                          NaN           NaN            NaN
# 1                                  Senso Unico      Sorrento       Campania
# 2                                 Corso Italia      Sorrento       Campania
# 3                              Via San Cesareo      Sorrento       Campania
# 4  Corso Italia, 134, 80067 Sorrento NA, Italy      Sorrento       Campania
#
#   location.postalCode location.crossStreet
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3               80067                  NaN
# 4               80067                  NaN

# %%
df_sorrento_food.shape
# Out:
# (47, 17)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_sorrento_food.columns if col.startswith('location.')] + ['id']
df_sorrento_food_filtered = df_sorrento_food.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sorrento_food_filtered['categories'] = df_sorrento_food_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sorrento_food_filtered.columns = [column.split('.')[-1] for column in df_sorrento_food_filtered.columns]

df_sorrento_food_filtered.head()
# Out:
#                         name          categories        lat        lng  \
# 0                 Piccadilly          Steakhouse  40.624804  14.376910
# 1      Sedil Dominova "2000"  Italian Restaurant  40.626030  14.373421
# 2  Gelateria Antonio Cafiero      Ice Cream Shop  40.626058  14.374916
# 3                Fatto Mo Mo  Italian Restaurant  40.625912  14.372960
# 4    Gelateria Chist' Ammore      Ice Cream Shop  40.625990  14.374684
#
#                                       labeledLatLngs  distance  cc country  \
# 0  [{'label': 'display', 'lat': 40.62480405205569...       175  IT  Italia
# 1  [{'label': 'display', 'lat': 40.62603038416951...       173  IT  Italia
# 2  [{'label': 'display', 'lat': 40.626058, 'lng':...       128  IT  Italia
# 3  [{'label': 'display', 'lat': 40.625912, 'lng':...       194  IT  Italia
# 4  [{'label': 'display', 'lat': 40.62599, 'lng': ...       121  IT  Italia
#
#                                     formattedAddress  \
# 0                                           [Italia]
# 1           [Senso Unico, Sorrento Campania, Italia]
# 2          [Corso Italia, Sorrento Campania, Italia]
# 3  [Via San Cesareo, 80067 Sorrento Campania, Ita...
# 4  [Corso Italia, 134, 80067 Sorrento NA, Italy, ...
#
#                                        address      city     state postalCode  \
# 0                                          NaN       NaN       NaN        NaN
# 1                                  Senso Unico  Sorrento  Campania        NaN
# 2                                 Corso Italia  Sorrento  Campania        NaN
# 3                              Via San Cesareo  Sorrento  Campania      80067
# 4  Corso Italia, 134, 80067 Sorrento NA, Italy  Sorrento  Campania      80067
#
#   crossStreet                        id
# 0         NaN  5542832d498ec52eb43563af
# 1         NaN  4cdea8af78ddf04d0fdb9b98
# 2         NaN  4c62d41dec94a593c9332aca
# 3         NaN  5da5980318ef670008a39a19
# 4         NaN  5b2c10322619ee002cc82178

# %%
df_sorrento_IT_filtered.to_csv('sorrentoITfiltered.csv', index=False)

# %%
df_sorrento_food_filtered.to_csv('sorrentoFoodfiltered.csv', index=False)

# %%
# Exported files 'sorrentoITfiltered and sorrentoFoodfiltered' to create usable database imported below

df_final_sorrento = pd.read_csv("SorrentoFoodPlaceRatings.csv")
df_final_sorrento.head()
# Out:
#                               name          categories  \
# 0                  Taverna Allegra  Italian Restaurant
# 1   Ristorante I Giardini Di Tasso  Italian Restaurant
# 2           Ristorante La Lanterna         Pizza Place
# 3  Ristorante Pizzeria S. Antonino  Italian Restaurant
# 4                        Zi'ntonio  Italian Restaurant
#
#                                  address        lat        lng  \
# 0                    Via della Pietà, 30  40.625331  14.374490
# 1                33 Via S.M. Della Pietà  40.624901  14.374449
# 2                  Via San Cesareo 23/25  40.626288  14.374937
# 3  Via S. Maria delle Grazie, 6 Sorrento  40.626590  14.374230
# 4                                    NaN  40.626574  14.375238
#
#                                       labeledLatLngs  distance  postalCode  \
# 0  [{'label': 'display', 'lat': 40.62533070025635...        55     80067.0
# 1  [{'label': 'display', 'lat': 40.6249006686078,...        32     80067.0
# 2  [{'label': 'display', 'lat': 40.6262879, 'lng'...       154     80067.0
# 3  [{'label': 'display', 'lat': 40.62658956072927...       194         NaN
# 4  [{'label': 'display', 'lat': 40.6265738589968,...       188         NaN
#
#    cc      city                          state country  \
# 0  IT  Sorrento                       Campania  Italia
# 1  IT  Sorrento                       Campania  Italia
# 2  IT  Sorrento  Città Metropolitana di Napoli  Italia
# 3  IT  Sorrento                       Campania  Italia
# 4  IT  Sorrento                       Campania  Italia
#
#                                     formattedAddress  \
# 0  ['Via della Pietà, 30', '80067 Sorrento Campan...
# 1  ['33 Via S.M. Della Pietà', '80067 Sorrento Ca...
# 2  ['Via San Cesareo 23/25', '80067 Sorrento Citt...
# 3  ['Via S. Maria delle Grazie, 6 Sorrento', 'Sor...
# 4                    ['Sorrento Campania', 'Italia']
#
#                          id  Ratings
# 0  4deab6b7fa76cc1b8aed74da      6.8
# 1  4fac1172e4b0256bff1842fe      8.6
# 2  4c1401a1a5eb76b01807c1b7      7.0
# 3  4e3ef11118a83d5b2858e7e5      7.8
# 4  4e974a96dab4ae9617e709cd      7.5

# %%
venues_map_sorrento_final = folium.Map(location=[latitude_sorrento, longitude_sorrento], zoom_start=15) # generate map centred around Sorrento, IT

# add a green circle marker to represent the center of Sorrento, IT
folium.features.CircleMarker(
    [latitude_sorrento, longitude_sorrento],
    radius=10,
    color='green',
    popup='Sorrento',
    fill = True,
    fill_color = 'green',
    fill_opacity = 0.6
).add_to(venues_map_sorrento_final)

# add the food places of Sorrento as blue circle markers
for lat, lng, label in zip(df_final_sorrento.lat, df_final_sorrento.lng, df_final_sorrento.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map_sorrento_final)

# display map
venues_map_sorrento_final
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
sorrento_final_cluster_map = folium.Map(location = [latitude_sorrento, longitude_sorrento], zoom_start = 15)

# instantiate a mark cluster object for the incidents in the dataframe
sorrento_grouping = plugins.MarkerCluster().add_to(sorrento_final_cluster_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_final_sorrento.lat, df_final_sorrento.lng, df_final_sorrento.categories):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(sorrento_grouping)

# display map
sorrento_final_cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'San Francisco'

geolocator = Nominatim(user_agent="foursquare_agent")
location_sf = geolocator.geocode(address)
latitude_sf = location_sf.latitude
longitude_sf = location_sf.longitude
print(latitude_sf, longitude_sf)
# Out:
# 37.7790262 -122.4199061

# %%
search_sf_italian = '4bf58dd8d48988d110941735' # Foursquare category ID for Italian Restaurants
radius_sf = 20000
limit_sf = 100
print('Search completed!')
# Out:
# Search completed!

# %%
url_sf_italian = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(search_sf_italian, CLIENT_ID, CLIENT_SECRET, latitude_sf, longitude_sf, VERSION, radius_sf, limit_sf)
url_sf_italian
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d110941735&client_id=ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y&client_secret=CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF&ll=37.7790262,-122.4199061&v=20180604&radius=20000&limit=100'

# %%
# Italian Restaurants search in San Francisco, CA

results_sf = requests.get(url_sf_italian).json()
print('San Francisco Results!')
# Out:
# San Francisco Results!

# %%
# assign relevant part of JSON to venues
venues_sf = results_sf['response']['venues']

# tranform venues into a dataframe
df_sanfran = json_normalize(venues_sf)
df_sanfran.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                          name  \
# 0  5907aa1c178a2a76066e0f59                        a Mano
# 1  5c0dd1ad5a2c91002c442f28            Gusto Pinsa Romana
# 2  4b36b9e6f964a520633b25e3            Scoma's Restaurant
# 3  4d856fbb5ad3a0930500e6fd                     Bar Bocce
# 4  53f914d8498e1ef0fe04474c  The Italian Homemade Company
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878710    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878710    False
# 2  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1590878710    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1590878710    False
#
#     location.address location.crossStreet  location.lat  location.lng  \
# 0       450 Hayes St       Octavia Street     37.776917   -122.423856
# 1       1000 Bush St                  NaN     37.789594   -122.413873
# 2  1965 Al Scoma Way     Jefferson Street     37.808956   -122.418235
# 3     1250 Bridgeway       at Humboldt St     37.859645   -122.484822
# 4   716 Columbus Ave                  NaN     37.801497   -122.411795
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 37.77691694534714...  ...     United States
# 1  [{'label': 'display', 'lat': 37.7895944763817,...  ...     United States
# 2  [{'label': 'display', 'lat': 37.80895628521507...  ...     United States
# 3  [{'label': 'display', 'lat': 37.85964521770759...  ...     United States
# 4  [{'label': 'display', 'lat': 37.80149747181165...  ...     United States
#
#                            location.formattedAddress venuePage.id delivery.id  \
# 0  [450 Hayes St (Octavia Street), San Francisco,...   1358641493         NaN
# 1  [1000 Bush St, San Francisco, CA 94109, United...          NaN     1041917
# 2  [1965 Al Scoma Way (Jefferson Street), San Fra...    179669645     2083805
# 3  [1250 Bridgeway (at Humboldt St), Sausalito, C...          NaN         NaN
# 4  [716 Columbus Ave, San Francisco, CA 94133, Un...          NaN     2121591
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1  https://www.grubhub.com/restaurant/gusto-pinsa...                grubhub
# 2  https://www.grubhub.com/restaurant/scomas-rest...                grubhub
# 3                                                NaN                    NaN
# 4  https://www.grubhub.com/restaurant/the-italian...                grubhub
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1  /delivery_provider_grubhub_20180129.png
# 2  /delivery_provider_grubhub_20180129.png
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#                  location.neighborhood
# 0                                  NaN
# 1                                  NaN
# 2  Fishermans Wharf, San Francisco, CA
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_sanfran.columns if col.startswith('location.')] + ['id']
df_sanfran_italian_filtered = df_sanfran.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sanfran_italian_filtered['categories'] = df_sanfran_italian_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sanfran_italian_filtered.columns = [column.split('.')[-1] for column in df_sanfran_italian_filtered.columns]
df_sanfran_italian_filtered.head()
# Out:
#                            name          categories            address  \
# 0                        a Mano  Italian Restaurant       450 Hayes St
# 1            Gusto Pinsa Romana  Italian Restaurant       1000 Bush St
# 2            Scoma's Restaurant  Seafood Restaurant  1965 Al Scoma Way
# 3                     Bar Bocce         Pizza Place     1250 Bridgeway
# 4  The Italian Homemade Company  Italian Restaurant   716 Columbus Ave
#
#         crossStreet        lat         lng  \
# 0    Octavia Street  37.776917 -122.423856
# 1               NaN  37.789594 -122.413873
# 2  Jefferson Street  37.808956 -122.418235
# 3    at Humboldt St  37.859645 -122.484822
# 4               NaN  37.801497 -122.411795
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 37.77691694534714...       419      94102  US
# 1  [{'label': 'display', 'lat': 37.7895944763817,...      1290      94109  US
# 2  [{'label': 'display', 'lat': 37.80895628521507...      3335      94133  US
# 3  [{'label': 'display', 'lat': 37.85964521770759...     10636      94965  US
# 4  [{'label': 'display', 'lat': 37.80149747181165...      2601      94133  US
#
#             city state        country  \
# 0  San Francisco    CA  United States
# 1  San Francisco    CA  United States
# 2  San Francisco    CA  United States
# 3      Sausalito    CA  United States
# 4  San Francisco    CA  United States
#
#                                     formattedAddress  \
# 0  [450 Hayes St (Octavia Street), San Francisco,...
# 1  [1000 Bush St, San Francisco, CA 94109, United...
# 2  [1965 Al Scoma Way (Jefferson Street), San Fra...
# 3  [1250 Bridgeway (at Humboldt St), Sausalito, C...
# 4  [716 Columbus Ave, San Francisco, CA 94133, Un...
#
#                           neighborhood                        id
# 0                                  NaN  5907aa1c178a2a76066e0f59
# 1                                  NaN  5c0dd1ad5a2c91002c442f28
# 2  Fishermans Wharf, San Francisco, CA  4b36b9e6f964a520633b25e3
# 3                                  NaN  4d856fbb5ad3a0930500e6fd
# 4                                  NaN  53f914d8498e1ef0fe04474c

# %%
df_sanfran_italian_filtered.to_csv('SanFranItalianFiltered.csv', index=False)

# %%
search_sf_seafood = '4bf58dd8d48988d1ce941735' # Foursquare category ID for Seafood Restaurants
radius_sf = 20000
limit_sf = 100
print('Search completed!')
# Out:
# Search completed!

# %%
url_sf_seafood = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(search_sf_seafood, CLIENT_ID, CLIENT_SECRET, latitude_sf, longitude_sf, VERSION, radius_sf, limit_sf)
url_sf_seafood
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d1ce941735&client_id=ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y&client_secret=CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF&ll=37.7790262,-122.4199061&v=20180604&radius=20000&limit=100'

# %%
# Seafood Restaurants search in San Francisco, CA

results_sf_seafood = requests.get(url_sf_seafood).json()
print('San Francisco Seafood Results!')
# Out:
# San Francisco Seafood Results!

# %%
# assign relevant part of JSON to venues
venues_sf_seafood = results_sf_seafood['response']['venues']

# tranform venues into a dataframe
df_sanfran_seafood = json_normalize(venues_sf_seafood)
df_sanfran_seafood.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  44d1ef97f964a52031361fe3                Swan Oyster Depot
# 1  4a975e5cf964a5207e2920e3            Bubba Gump Shrimp Co.
# 2  55876ba3498e08016ede6a73                     Hook Fish Co
# 3  4e5aa906a8098920b3cefb4c  Salito's Crab House & Prime Rib
# 4  4b36b9e6f964a520633b25e3               Scoma's Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
# 1  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
# 2  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
# 3  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
# 4  [{'id': '4bf58dd8d48988d1ce941735', 'name': 'S...  v-1590878710    False
#
#      location.address              location.crossStreet  location.lat  \
# 0        1517 Polk St  btwn Sacramento & California St.     37.790931
# 1  39 Piers Box M-211                               NaN     37.811050
# 2      4542 Irving St                   btw 47th & 46th     37.762323
# 3      1200 Bridgeway                      at Turney St     37.859912
# 4   1965 Al Scoma Way                  Jefferson Street     37.808956
#
#    location.lng                            location.labeledLatLngs  ...  \
# 0   -122.420759  [{'label': 'display', 'lat': 37.79093079070444...  ...
# 1   -122.410418  [{'label': 'display', 'lat': 37.8110504, 'lng'...  ...
# 2   -122.506827  [{'label': 'display', 'lat': 37.76232260031848...  ...
# 3   -122.485287  [{'label': 'display', 'lat': 37.85991177021466...  ...
# 4   -122.418235  [{'label': 'display', 'lat': 37.80895628521507...  ...
#
#    location.country                          location.formattedAddress  \
# 0     United States  [1517 Polk St (btwn Sacramento & California St...
# 1     United States  [39 Piers Box M-211, San Francisco, CA 94133, ...
# 2     United States  [4542 Irving St (btw 47th & 46th), San Francis...
# 3     United States  [1200 Bridgeway (at Turney St), Sausalito, CA ...
# 4     United States  [1965 Al Scoma Way (Jefferson Street), San Fra...
#
#                  location.neighborhood venuePage.id delivery.id  \
# 0                                  NaN          NaN         NaN
# 1                                  NaN          NaN         NaN
# 2                         Outer Sunset          NaN         NaN
# 3                                  NaN     36095338         NaN
# 4  Fishermans Wharf, San Francisco, CA    179669645     2083805
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4  https://www.grubhub.com/restaurant/scomas-rest...                grubhub
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#                delivery.provider.icon.name
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_sanfran_seafood.columns if col.startswith('location.')] + ['id']
df_sanfran_seafood_filtered = df_sanfran_seafood.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sanfran_seafood_filtered['categories'] = df_sanfran_seafood_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sanfran_seafood_filtered.columns = [column.split('.')[-1] for column in df_sanfran_seafood_filtered.columns]
df_sanfran_seafood_filtered.head()
# Out:
#                               name          categories             address  \
# 0                Swan Oyster Depot  Seafood Restaurant        1517 Polk St
# 1            Bubba Gump Shrimp Co.  Seafood Restaurant  39 Piers Box M-211
# 2                     Hook Fish Co  Seafood Restaurant      4542 Irving St
# 3  Salito's Crab House & Prime Rib  Seafood Restaurant      1200 Bridgeway
# 4               Scoma's Restaurant  Seafood Restaurant   1965 Al Scoma Way
#
#                         crossStreet        lat         lng  \
# 0  btwn Sacramento & California St.  37.790931 -122.420759
# 1                               NaN  37.811050 -122.410418
# 2                   btw 47th & 46th  37.762323 -122.506827
# 3                      at Turney St  37.859912 -122.485287
# 4                  Jefferson Street  37.808956 -122.418235
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 37.79093079070444...      1327      94109  US
# 1  [{'label': 'display', 'lat': 37.8110504, 'lng'...      3661      94133  US
# 2  [{'label': 'display', 'lat': 37.76232260031848...      7871      94122  US
# 3  [{'label': 'display', 'lat': 37.85991177021466...     10683      94965  US
# 4  [{'label': 'display', 'lat': 37.80895628521507...      3335      94133  US
#
#             city state        country  \
# 0  San Francisco    CA  United States
# 1  San Francisco    CA  United States
# 2  San Francisco    CA  United States
# 3      Sausalito    CA  United States
# 4  San Francisco    CA  United States
#
#                                     formattedAddress  \
# 0  [1517 Polk St (btwn Sacramento & California St...
# 1  [39 Piers Box M-211, San Francisco, CA 94133, ...
# 2  [4542 Irving St (btw 47th & 46th), San Francis...
# 3  [1200 Bridgeway (at Turney St), Sausalito, CA ...
# 4  [1965 Al Scoma Way (Jefferson Street), San Fra...
#
#                           neighborhood                        id
# 0                                  NaN  44d1ef97f964a52031361fe3
# 1                                  NaN  4a975e5cf964a5207e2920e3
# 2                         Outer Sunset  55876ba3498e08016ede6a73
# 3                                  NaN  4e5aa906a8098920b3cefb4c
# 4  Fishermans Wharf, San Francisco, CA  4b36b9e6f964a520633b25e3

# %%
df_sanfran_seafood_filtered.to_csv('SanFranSeafoodFiltered.csv', index=False)

# %%
search_sf_steakhouse = '4bf58dd8d48988d1cc941735' # Foursquare category ID for Steakhouse Restaurants
radius_sf = 20000
limit_sf = 100
print('Search completed!')
# Out:
# Search completed!

# %%
url_sf_steakhouse = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(search_sf_steakhouse, CLIENT_ID, CLIENT_SECRET, latitude_sf, longitude_sf, VERSION, radius_sf, limit_sf)
url_sf_steakhouse
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d1cc941735&client_id=ERQIST1V00YZ4T1KEQVCFWYQMFDQ0HCET2K05DXMPZXDEU3Y&client_secret=CAEERP15EEK0S05RLF4H1VUFGVMAR3I1S2J4XMOFDCB3E2BF&ll=37.7790262,-122.4199061&v=20180604&radius=20000&limit=100'

# %%
# Steakhouse Restaurants search in San Francisco, CA

results_sf_steakhouse = requests.get(url_sf_steakhouse).json()
print('San Francisco Steakhouse Results!')
# Out:
# San Francisco Steakhouse Results!

# %%
# assign relevant part of JSON to venues
venues_sf_steakhouse = results_sf_steakhouse['response']['venues']

# tranform venues into a dataframe
df_sanfran_steakhouse = json_normalize(venues_sf_steakhouse)
df_sanfran_steakhouse.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                name  \
# 0  4afb7c6df964a5204d1e22e3  Mayes Oyster House
# 1  5d47848feadfb0000721c4e1    El Osito Central
# 2  538173ec498ebb8d531f8aaa         The Kitchen
# 3  5800473938fa42d688c9dd19               Grill
# 4  4f775ffce4b0d693691b0913  Barrett Ave Market
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1590878711    False
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590878711    False
# 2  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590878711    False
# 3  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590878711    False
# 4  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590878711    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0     1233 Polk St           at Fern St     37.788338   -122.420279
# 1              NaN                  NaN     37.896765   -122.304064
# 2      341 13th St                  NaN     37.802133   -122.268854
# 3              NaN                  NaN     37.786526   -122.401550
# 4              NaN                  NaN     37.937115   -122.353600
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 37.7883383584513,...  ...     United States
# 1  [{'label': 'display', 'lat': 37.896765, 'lng':...  ...     United States
# 2  [{'label': 'display', 'lat': 37.80213300000000...  ...     United States
# 3  [{'label': 'display', 'lat': 37.786526, 'lng':...  ...     United States
# 4  [{'label': 'display', 'lat': 37.93711471557617...  ...     United States
#
#                            location.formattedAddress venuePage.id delivery.id  \
# 0  [1233 Polk St (at Fern St), San Francisco, CA ...     84321436         NaN
# 1                  [Albany, CA 94706, United States]          NaN         NaN
# 2    [341 13th St, Oakland, CA 94612, United States]          NaN         NaN
# 3           [San Francisco, CA 94105, United States]          NaN         NaN
# 4                [Richmond, CA 94801, United States]          NaN         NaN
#
#   delivery.url delivery.provider.name delivery.provider.icon.prefix  \
# 0          NaN                    NaN                           NaN
# 1          NaN                    NaN                           NaN
# 2          NaN                    NaN                           NaN
# 3          NaN                    NaN                           NaN
# 4          NaN                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_sanfran_steakhouse.columns if col.startswith('location.')] + ['id']
df_sanfran_steakhouse_filtered = df_sanfran_steakhouse.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_sanfran_steakhouse_filtered['categories'] = df_sanfran_steakhouse_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_sanfran_steakhouse_filtered.columns = [column.split('.')[-1] for column in df_sanfran_steakhouse_filtered.columns]
df_sanfran_steakhouse_filtered.head()
# Out:
#                  name  categories       address crossStreet        lat  \
# 0  Mayes Oyster House   Nightclub  1233 Polk St  at Fern St  37.788338
# 1    El Osito Central  Steakhouse           NaN         NaN  37.896765
# 2         The Kitchen  Steakhouse   341 13th St         NaN  37.802133
# 3               Grill  Steakhouse           NaN         NaN  37.786526
# 4  Barrett Ave Market  Steakhouse           NaN         NaN  37.937115
#
#           lng                                     labeledLatLngs  distance  \
# 0 -122.420279  [{'label': 'display', 'lat': 37.7883383584513,...      1037
# 1 -122.304064  [{'label': 'display', 'lat': 37.896765, 'lng':...     16598
# 2 -122.268854  [{'label': 'display', 'lat': 37.80213300000000...     13534
# 3 -122.401550  [{'label': 'display', 'lat': 37.786526, 'lng':...      1817
# 4 -122.353600  [{'label': 'display', 'lat': 37.93711471557617...     18538
#
#   postalCode  cc           city state        country  \
# 0      94109  US  San Francisco    CA  United States
# 1      94706  US         Albany    CA  United States
# 2      94612  US        Oakland    CA  United States
# 3      94105  US  San Francisco    CA  United States
# 4      94801  US       Richmond    CA  United States
#
#                                     formattedAddress neighborhood  \
# 0  [1233 Polk St (at Fern St), San Francisco, CA ...          NaN
# 1                  [Albany, CA 94706, United States]          NaN
# 2    [341 13th St, Oakland, CA 94612, United States]          NaN
# 3           [San Francisco, CA 94105, United States]          NaN
# 4                [Richmond, CA 94801, United States]          NaN
#
#                          id
# 0  4afb7c6df964a5204d1e22e3
# 1  5d47848feadfb0000721c4e1
# 2  538173ec498ebb8d531f8aaa
# 3  5800473938fa42d688c9dd19
# 4  4f775ffce4b0d693691b0913

# %%
df_sanfran_steakhouse_filtered.to_csv('SanFranSteakhouseFiltered.csv', index=False)

# %%
# import combined files for San Francisco Italian, seafood, and steakhouse restaurants

df_sanfran_final = pd.read_csv("SanFranAllFoodPlaces05262020.csv")
df_sanfran_final.head()
# Out:
#                          Name                Type                       Group  \
# 0           Swan Oyster Depot  Seafood Restaurant           Swan Oyster Depot
# 1             Tacos San Buena       Burrito Place             Tacos San Buena
# 2       California Fish Grill  Seafood Restaurant       California Fish Grill
# 3              Live Sushi Bar    Sushi Restaurant              Live Sushi Bar
# 4  San Francisco Fish Company  Seafood Restaurant  San Francisco Fish Company
#
#                 address                       crossStreet          Y  \
# 0          1517 Polk St  btwn Sacramento & California St.  37.790931
# 1       400 Pacific Ave                        at Sansome  37.797583
# 2   153C Serramonte Ctr                               NaN  37.670923
# 3          2001 17th St                            Kansas  37.764694
# 4  1 Ferry Building #31                   The Embarcadero  37.795194
#
#             X                                     labeledLatLngs  distance  \
# 0 -122.420759  [{'label': 'display', 'lat': 37.79093079070444...      1327
# 1 -122.401669  [{'label': 'display', 'lat': 37.79758284467872...      2615
# 2 -122.467751  [{'label': 'display', 'lat': 37.67092320712261...     12749
# 3 -122.403676  [{'label': 'display', 'lat': 37.76469373053839...      2141
# 4 -122.393232  [{'label': 'display', 'lat': 37.79519376938006...      2957
#
#    postalCode  cc           city state        country  \
# 0     94109.0  US  San Francisco    CA  United States
# 1     94133.0  US  San Francisco    CA  United States
# 2     94015.0  US      Daly City    CA  United States
# 3     94103.0  US  San Francisco    CA  United States
# 4     94111.0  US  San Francisco    CA  United States
#
#                                     formattedAddress neighborhood  \
# 0  ['1517 Polk St (btwn Sacramento & California S...          NaN
# 1  ['400 Pacific Ave (at Sansome)', 'San Francisc...          NaN
# 2  ['153C Serramonte Ctr', 'Daly City, CA 94015',...          NaN
# 3  ['2001 17th St (Kansas)', 'San Francisco, CA 9...          NaN
# 4  ['1 Ferry Building #31 (The Embarcadero)', 'Sa...          NaN
#
#                          id
# 0  44d1ef97f964a52031361fe3
# 1  4a83179df964a52015fa1fe3
# 2  5a382e33c4df1d2b8838454d
# 3  4a445686f964a52077a71fe3
# 4  4a2d819bf964a520b9971fe3

# %%
df_sanfran_final.shape
# Out:
# (147, 17)

# %%
# create San Francisco map and display it
sanfran_final_map = folium.Map(location=[latitude_sf, longitude_sf], zoom_start=12)

# display the map of San Francisco
sanfran_final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# instantiate a feature group for the incidents in the dataframe
sf_food_final = folium.map.FeatureGroup()

# loop through the restaurants and add each to the feature group
for lat, lng, in zip(df_sanfran_final.Y, df_sanfran_final.X):
    sf_food_final.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
sanfran_final_map.add_child(sf_food_final)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
sanfran_final_map = folium.Map(location = [latitude_sf, longitude_sf], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
sanfran_food_cluster_final = plugins.MarkerCluster().add_to(sanfran_final_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_sanfran_final.Y, df_sanfran_final.X, df_sanfran_final.Type):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(sanfran_food_cluster_final)

# display map
sanfran_final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
